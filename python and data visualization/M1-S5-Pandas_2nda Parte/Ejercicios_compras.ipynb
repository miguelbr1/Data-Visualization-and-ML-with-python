# %% [markdown]
# ___
#
# # Ejercicio 2 de Pandas: Ecommerce (compras)
#
# En este ejercicio, se le proporcionarán datos falsos sobre algunas compras realizadas a través de Amazon. Por favor siga las instrucciones y complete las tareas propuestas.
#
# La mayoría de las tareas se pueden resolver de diferentes maneras. El nivel de dificultad es incremental.
#
# Disculpe cualquier cosa que no tenga sentido en el "mundo real", todos los datos son falsos y fueron inventados para este taller.
#
# También tenga en cuenta que todas estas preguntas se pueden responder con una línea de código.
# ____
# ** Importe pandas y lea en el archivo de compras de comercio electrónico (compras.csv) y almacénelo en un dataframe llamado ecom. **
# ____

# %%
# ESCRIBA SU CODIGO AQUI 
import pandas as pd

# %%
# ESCRIBA SU CODIGO AQUI 
ecom = pd.read_csv("compras.csv")

# %% [markdown]
# ** Muestre las primeras 5 filas del DataFrame para verificar que leyó los datos correctamente. **

# %%
# ESCRIBA SU CODIGO AQUI PARA NO BORRAR EL RESULTADO ESPERADO
ecom.head(5)
# Out:
#                                              Address    Lot AM or PM  \
# 0  16629 Pace Camp Apt. 448\nAlexisborough, NE 77...  46 in       PM
# 1  9374 Jasmine Spurs Suite 508\nSouth John, TN 8...  28 rn       PM
# 2                   Unit 0065 Box 5052\nDPO AP 27450  94 vE       PM
# 3              7780 Julia Fords\nNew Stacy, WA 45798  36 vm       PM
# 4  23012 Munoz Drive Suite 337\nNew Cynthia, TX 5...  20 IE       AM
#
#                                         Browser Info  \
# 0  Opera/9.56.(X11; Linux x86_64; sl-SI) Presto/2...
# 1  Opera/8.93.(Windows 98; Win 9x 4.90; en-US) Pr...
# 2  Mozilla/5.0 (compatible; MSIE 9.0; Windows NT ...
# 3  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_8_0 ...
# 4  Opera/9.58.(X11; Linux x86_64; it-IT) Presto/2...
#
#                            Company       Credit Card CC Exp Date  \
# 0                  Martinez-Herman  6011929061123406       02/20
# 1  Fletcher, Richards and Whitaker  3337758169645356       11/18
# ...

# %%
# NO USAR ESTA CELDA
# Out:
#                                              Address    Lot AM or PM  \
# 0  16629 Pace Camp Apt. 448\nAlexisborough, NE 77...  46 in       PM
# 1  9374 Jasmine Spurs Suite 508\nSouth John, TN 8...  28 rn       PM
# 2                   Unit 0065 Box 5052\nDPO AP 27450  94 vE       PM
# 3              7780 Julia Fords\nNew Stacy, WA 45798  36 vm       PM
# 4  23012 Munoz Drive Suite 337\nNew Cynthia, TX 5...  20 IE       AM
#
#                                         Browser Info  \
# 0  Opera/9.56.(X11; Linux x86_64; sl-SI) Presto/2...
# 1  Opera/8.93.(Windows 98; Win 9x 4.90; en-US) Pr...
# 2  Mozilla/5.0 (compatible; MSIE 9.0; Windows NT ...
# 3  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_8_0 ...
# 4  Opera/9.58.(X11; Linux x86_64; it-IT) Presto/2...
#
#                            Company       Credit Card CC Exp Date  \
# 0                  Martinez-Herman  6011929061123406       02/20
# 1  Fletcher, Richards and Whitaker  3337758169645356       11/18
# ...

# %% [markdown]
# ** ¿Cuántas filas y columnas hay? **

# %%
# ESCRIBA SU CODIGO AQUI PARA NO BORRAR EL RESULTADO ESPERADO

# %%
# NO USAR ESTA CELDA
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
# Address             10000 non-null object
# Lot                 10000 non-null object
# AM or PM            10000 non-null object
# Browser Info        10000 non-null object
# Company             10000 non-null object
# Credit Card         10000 non-null int64
# CC Exp Date         10000 non-null object
# CC Security Code    10000 non-null int64
# CC Provider         10000 non-null object
# Email               10000 non-null object
# Job                 10000 non-null object
# IP Address          10000 non-null object
# Language            10000 non-null object
# Purchase Price      10000 non-null float64
# dtypes: float64(1), int64(2), object(11)
# memory usage: 1.1+ MB

# %% [markdown]
# ** ¿Cuál es el precio de compra promedio (Purchase Price)? **

# %%
# ESCRIBA SU CODIGO AQUI PARA NO BORRAR EL RESULTADO ESPERADO

# %%
# NO USAR ESTA CELDA
# Out:
# 50.34730200000025

# %% [markdown]
# ** ¿Cuál fue el precio de compra máximo? ¿y el mínimo? **

# %%
# ESCRIBA SU CODIGO AQUI PARA NO BORRAR EL RESULTADO ESPERADO

# %%
# NO USAR ESTA CELDA
# Out:
# 99.99

# %%
# ESCRIBA SU CODIGO AQUI PARA NO BORRAR EL RESULTADO ESPERADO

# %%
# NO USAR ESTA CELDA
# Out:
# 0.0

# %% [markdown]
# ** ¿Cuánta gente tiene Español 'es' como su idioma (Language) en la página web? **

# %%
# ESCRIBA SU CODIGO AQUI PARA NO BORRAR EL RESULTADO ESPERADO
ecom[ecom["Language"]=="es"].count()
# Out:
# Address             1095
# Lot                 1095
# AM or PM            1095
# Browser Info        1095
# Company             1095
# Credit Card         1095
# CC Exp Date         1095
# CC Security Code    1095
# CC Provider         1095
# Email               1095
# Job                 1095
# IP Address          1095
# Language            1095
# Purchase Price      1095
# dtype: int64

# %%
# NO USAR ESTA CELDA
# Out:
# Address             1095
# Lot                 1095
# AM or PM            1095
# Browser Info        1095
# Company             1095
# Credit Card         1095
# CC Exp Date         1095
# CC Security Code    1095
# CC Provider         1095
# Email               1095
# Job                 1095
# IP Address          1095
# Language            1095
# Purchase Price      1095
# dtype: int64

# %% [markdown]
# ** ¿Cuánta gente tiene el cargo (Job) de abogado ('Lawyer')? **

# %%
# ESCRIBA SU CODIGO AQUI PARA NO BORRAR EL RESULTADO ESPERADO

# %%
# NO USAR ESTA CELDA
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 30 entries, 470 to 9979
# Data columns (total 14 columns):
# Address             30 non-null object
# Lot                 30 non-null object
# AM or PM            30 non-null object
# Browser Info        30 non-null object
# Company             30 non-null object
# Credit Card         30 non-null int64
# CC Exp Date         30 non-null object
# CC Security Code    30 non-null int64
# CC Provider         30 non-null object
# Email               30 non-null object
# Job                 30 non-null object
# IP Address          30 non-null object
# Language            30 non-null object
# Purchase Price      30 non-null float64
# dtypes: float64(1), int64(2), object(11)
# memory usage: 3.5+ KB

# %% [markdown]
# ** ¿Cuánta gente hizo la compra durante la mañana (AM) y cuántos durante la tarde (PM)? **

# %%
# ESCRIBA SU CODIGO AQUI PARA NO BORRAR EL RESULTADO ESPERADO

# %%
# NO USAR ESTA CELDA
# Out:
# PM    5068
# AM    4932
# Name: AM or PM, dtype: int64

# %% [markdown]
# ** ¿Cuáles son los 5 cargos (Jobs) más comunes? **

# %%
# ESCRIBA SU CODIGO AQUI PARA NO BORRAR EL RESULTADO ESPERADO

# %%
# NO USAR ESTA CELDA
# Out:
# Interior and spatial designer    31
# Lawyer                           30
# Social researcher                28
# Purchasing manager               27
# Designer, jewellery              27
# Name: Job, dtype: int64

# %% [markdown]
# ** Alguien hizo una compra desde Lot: "90 WT", ¿cuál fue el precio de compra de esta transacción? **

# %%
# ESCRIBA SU CODIGO AQUI PARA NO BORRAR EL RESULTADO ESPERADO

# %%
# NO USAR ESTA CELDA
# Out:
# 513    75.1
# Name: Purchase Price, dtype: float64

# %% [markdown]
# ** ¿Cuál es el email de la persona con el número de tarjeta de crédito: 4926535242672853? **

# %%
# ESCRIBA SU CODIGO AQUI PARA NO BORRAR EL RESULTADO ESPERADO

# %%
# NO USAR ESTA CELDA
# Out:
# 1234    bondellen@williams-garza.com
# Name: Email, dtype: object

# %% [markdown]
# ** ¿Cuántas personas tienen tarjetas American Express *e* hicieron una compra por más de $95?**

# %%
# ESCRIBA SU CODIGO AQUI PARA NO BORRAR EL RESULTADO ESPERADO

# %%
# NO USAR ESTA CELDA
# Out:
# Address             39
# Lot                 39
# AM or PM            39
# Browser Info        39
# Company             39
# Credit Card         39
# CC Exp Date         39
# CC Security Code    39
# CC Provider         39
# Email               39
# Job                 39
# IP Address          39
# Language            39
# Purchase Price      39
# dtype: int64

# %% [markdown]
# ** ¿Cuántas personas tienen una tarjeta de crédito que expira en 2025? **

# %%
# ESCRIBA SU CODIGO AQUI PARA NO BORRAR EL RESULTADO ESPERADO

# %%
# NO USAR ESTA CELDA
# Out:
# 1033

# %% [markdown]
# ** ¿Cuáles son los 5 proveedores de correo electrónico más comunes? (e.g. gmail.com, yahoo.com, etc...) **

# %%
# ESCRIBA SU CODIGO AQUI PARA NO BORRAR EL RESULTADO ESPERADO

# %%
# NO USAR ESTA CELDA
# Out:
# hotmail.com     1638
# yahoo.com       1616
# gmail.com       1605
# smith.com         42
# williams.com      37
# Name: Email, dtype: int64

# %% [markdown]
# ** ¿Cree dos nuevos dataframes del dataframe ecom ('Purchase Price', 'Job') y realice la concatenación en un nuevo dataframe **

# %%
# ESCRIBA SU CODIGO AQUI PARA NO BORRAR EL RESULTADO ESPERADO

# %%
# NO USAR ESTA CELDA
# Out:
#       Purchase Price                                     Job
# 0              98.14  Scientist, product/process development
# 1              70.73                       Drilling engineer
# 2               0.95                Customer service manager
# 3              78.04                       Drilling engineer
# 4              77.82                             Fine artist
# 5              25.15                       Fish farm manager
# 6              88.56                                  Dancer
# 7              44.25                         Event organiser
# 8              59.54                       Financial manager
# 9              95.63                      Forensic scientist
# 10             96.89           Development worker, community
# 11             19.26                 Diagnostic radiographer
# 12             39.65                      Surveyor, quantity
# 13              8.93    Accountant, chartered public finance
# ...

# %% [markdown]
# ** Ordene el nuevo dataframe generado by ('Purchase Price')**

# %%
# ESCRIBA SU CODIGO AQUI PARA NO BORRAR EL RESULTADO ESPERADO

# %%
# NO USAR ESTA CELDA
# Out:
#       Purchase Price                                      Job
# 5487            0.00                            Stage manager
# 2876            0.00                     Biomedical scientist
# 6863            0.01               Television camera operator
# 8656            0.02    Product/process development scientist
# 2783            0.02                               IT trainer
# 550             0.03             Research officer, government
# 6647            0.03              Civil engineer, contracting
# 4280            0.04                         Surveyor, mining
# 8937            0.06                Radio broadcast assistant
# 2657            0.07                              Optometrist
# 8731            0.08                    Multimedia specialist
# 1530            0.10                      Surveyor, insurance
# 1691            0.12                 Magazine features editor
# 2438            0.14                  Insurance risk surveyor
# ...

# %% [markdown]
# ** Ordene el nuevo dataframe generado by ('Job')**

# %%
# ESCRIBA SU CODIGO AQUI PARA NO BORRAR EL RESULTADO ESPERADO

# %%
# NO USAR ESTA CELDA
# Out:
#       Purchase Price                    Job
# 9931           64.41     Academic librarian
# 4214           56.46     Academic librarian
# 8499           22.56     Academic librarian
# 7769           95.15     Academic librarian
# 3914           15.37     Academic librarian
# 8234           65.87     Academic librarian
# 6589            0.76     Academic librarian
# 2339           65.67     Academic librarian
# 7103           29.55     Academic librarian
# 1646           58.66     Academic librarian
# 1461           53.01     Academic librarian
# 6564           33.63  Accommodation manager
# 9628           57.89  Accommodation manager
# 963            24.02  Accommodation manager
# 5923           19.95  Accommodation manager
# 7741           58.07  Accommodation manager
# 1306           48.58  Accommodation manager
# 2422            9.06  Accommodation manager
# 4509           34.62  Accommodation manager
# 4013           32.28  Accommodation manager
# ...

# %% [markdown]
# ** Realice la concatenación de 'CC Security Code' y 'CC Provider' usando .join**

# %%
# ESCRIBA SU CODIGO AQUI PARA NO BORRAR EL RESULTADO ESPERADO

# %%
# NO USAR ESTA CELDA
# Out:
#       CC Security Code                  CC Provider
# 0                  900                 JCB 16 digit
# 1                  561                   Mastercard
# 2                  699                 JCB 16 digit
# 3                  384                     Discover
# 4                  678  Diners Club / Carte Blanche
# 5                 7169                     Discover
# 6                  714                VISA 16 digit
# 7                  256                VISA 13 digit
# 8                  899                 JCB 16 digit
# 9                  931             American Express
# 10                 754                      Voyager
# 11                9717                 JCB 15 digit
# 12                 119                VISA 16 digit
# 13                 557                VISA 16 digit
# 14                 427                VISA 16 digit
# 15                 404  Diners Club / Carte Blanche
# 16                 285  Diners Club / Carte Blanche
# ...

# %% [markdown]
# ** Extra: Crear dos dataframes y hacer un merge con 'subject_id' **

# %%
# NO USAR ESTA CELDA (Dataframe 1)
# Out:
#   subject_id  test_id
# 0          1       51
# 1          2       15
# 2          3       15
# 3          4       61
# 4          5       16
# 5          7       14
# 6          8       15
# 7          9        1
# 8         10       61

# %%
# NO USAR ESTA CELDA (Dataframe 2)
# Out:
#   subject_id first_name  last_name
# 0          0       Alex   González
# 1          1     Andres   Martínez
# 2          2    Aurelio    Perdomo
# 3          3     Alicia  Rodríguez
# 4          4       Beto     Cediel
# 5          5      Bryan       Bula
# 6          6    Gustavo   Restrepo
# 7          7      Oscar       Lara
# 8          8     Leonel  Contreras

# %%
# ESCRIBA SU CODIGO AQUI PARA NO BORRAR EL RESULTADO ESPERADO

# %%
# NO USAR ESTA CELDA
# Out:
#   subject_id  test_id first_name  last_name
# 0          1       51     Andres   Martínez
# 1          2       15    Aurelio    Perdomo
# 2          3       15     Alicia  Rodríguez
# 3          4       61       Beto     Cediel
# 4          5       16      Bryan       Bula
# 5          7       14      Oscar       Lara
# 6          8       15     Leonel  Contreras
